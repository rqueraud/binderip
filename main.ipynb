# %% [markdown]
# # Environnement Elasticsearch sous Binder
#
# Lancer Elasticsearch via la cellule `bash` ci-dessous, puis attendre quelques secondes son lancement.
#
# Une fois lancé, vous pouvez executer le reste des cellules.

# %%
# %%bash
# ./elasticsearch-7.15.2/bin/elasticsearch &
# Out:
# Requirement already satisfied: pymongo in ./.local/lib/python3.9/site-packages (3.12.1)
# Requirement already satisfied: pandas in ./.local/lib/python3.9/site-packages (1.3.4)
# Collecting xmltodict
#   Downloading xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in ./.local/lib/python3.9/site-packages (from pandas) (1.21.3)
# Requirement already satisfied: pytz>=2017.3 in ./.local/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.12.0

# %%
import pandas as pd
import xmltodict
from elasticsearch import Elasticsearch

# %%
def load_data(filepath):
    with open(filepath,'r') as f:
        xml_data = f.read()
    json_data = xmltodict.parse(xml_data)
    json_data = json_data[list(json_data.keys())[0]]["row"]
    json_data = [dict(orderedDict) for orderedDict in json_data]

    df_data = pd.json_normalize(json_data)
    df_data
    return json_data, df_data
    
posts, df_posts = load_data("./data/movies-stackexchange/Posts.xml")

df_posts
# Out:
#           @Id @PostTypeId @AcceptedAnswerId            @CreationDate @Score  \
# 0           1           1              2776  2011-11-30T19:15:54.070     29
# 1           2           2               NaN  2011-11-30T19:37:10.510     14
# 2           3           1               814  2011-11-30T19:41:14.960     29
# 3           4           1               120  2011-11-30T19:42:45.470     59
# 4           6           1                21  2011-11-30T19:44:55.593     16
# ...       ...         ...               ...                      ...    ...
# 59064  112876           2               NaN  2021-02-27T19:45:26.137      1
# 59065  112877           1               NaN  2021-02-27T21:55:10.713     -1
# 59066  112878           2               NaN  2021-02-27T23:49:44.430      0
# 59067  112879           2               NaN  2021-02-28T01:36:14.990      1
# 59068  112880           1               NaN  2021-02-28T03:31:49.420      0
#
#       @ViewCount                                              @Body  \
# 0           7036  <p>Some comedian/actors are given creative fre...
# 1            NaN  <p>According to the <a href="http://www.imdb.c...
# 2           1852  <p>In his Star Wars Episode 1 <a href="https:/...
# 3           3376  <p>I'm a big fan of the Pink Panther movies (t...
# 4           7023  <p>At the end of the movie, adult Jack (Sean P...
# ...          ...                                                ...
# 59064        NaN  <p>Out-of-universe, and from a commercial poin...
# 59065         16  <p>At the end of Thor:Ragnarok we see Thanos' ...
# 59066        NaN  <p>Stapling a dirty deep wound like that is a ...
# 59067        NaN  <p>I decoded it as best i could and tried usin...
# 59068          3  <p>There have been questions about a plot hole...
#
#       @OwnerUserId @LastEditorUserId            @LastEditDate  ...  \
# 0               11              3650  2013-09-25T14:15:14.257  ...
# 1               31               NaN                      NaN  ...
# 2               41             70064  2019-05-15T02:23:45.307  ...
# 3               22                22  2013-08-17T20:17:23.187  ...
# 4               34                49  2013-06-06T12:05:01.613  ...
# ...            ...               ...                      ...  ...
# 59064        67810               NaN                      NaN  ...
# 59065        75752               NaN                      NaN  ...
# 59066        86252               NaN                      NaN  ...
# 59067        86253               NaN                      NaN  ...
# 59068        86255               NaN                      NaN  ...
#
#                                                    @Tags @AnswerCount  \
# 0                                     <wedding-crashers>            2
# 1                                                    NaN          NaN
# 2                                  <analysis><star-wars>            2
# 3                             <comedy><the-pink-panther>            5
# 4      <plot-explanation><analysis><ending><the-tree-...            2
# ...                                                  ...          ...
# 59064                                                NaN          NaN
# 59065  <marvel-cinematic-universe><avengers-infinity-...            0
# 59066                                                NaN          NaN
# 59067                                                NaN          NaN
# 59068                           <plot-explanation><2067>            0
#
#       @CommentCount @ContentLicense @ParentId @FavoriteCount  \
# 0                 0    CC BY-SA 3.0       NaN            NaN
# 1                 3    CC BY-SA 3.0         1            NaN
# 2                 2    CC BY-SA 4.0       NaN            NaN
# 3                 2    CC BY-SA 3.0       NaN              2
# 4                 0    CC BY-SA 3.0       NaN              1
# ...             ...             ...       ...            ...
# 59064             0    CC BY-SA 4.0    112859            NaN
# 59065             0    CC BY-SA 4.0       NaN            NaN
# 59066             0    CC BY-SA 4.0     42997            NaN
# 59067             0    CC BY-SA 4.0    110629            NaN
# 59068             0    CC BY-SA 4.0       NaN            NaN
#
#       @LastEditorDisplayName              @ClosedDate @OwnerDisplayName  \
# 0                        NaN                      NaN               NaN
# 1                        NaN                      NaN               NaN
# 2                        NaN                      NaN               NaN
# 3                        NaN                      NaN               NaN
# 4                        NaN                      NaN               NaN
# ...                      ...                      ...               ...
# 59064                    NaN                      NaN               NaN
# 59065                    NaN  2021-02-27T23:05:40.893               NaN
# 59066                    NaN                      NaN               NaN
# 59067                    NaN                      NaN               NaN
# 59068                    NaN                      NaN               NaN
#
#       @CommunityOwnedDate
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 59064                 NaN
# 59065                 NaN
# 59066                 NaN
# 59067                 NaN
# 59068                 NaN
#
# [59069 rows x 22 columns]

# %%
es = Elasticsearch()

doc = posts[0]
res = es.index(index="posts", id=1, document=doc)
print(res['result'])

res = es.get(index="test-index", id=1)
print(res['_source'])
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipykernel_70/1441333483.py in <module>
#       2 db = client.movies
#       3
# ----> 4 db.posts.insert_one(posts[0])
#
# ~/.local/lib/python3.9/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     703         write_concern = self._write_concern_for(session)
#     704         return InsertOneResult(
# --> 705             self._insert(document,
#     706                          write_concern=write_concern,
#     707                          bypass_doc_val=bypass_document_validation,
#
# ~/.local/lib/python3.9/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     618         """Internal insert helper."""
#     619         if isinstance(docs, abc.Mapping):
# --> 620             return self._insert_one(
#     621                 docs, ordered, check_keys, manipulate, write_concern, op_id,
#     622                 bypass_doc_val, session)
#
# ~/.local/lib/python3.9/site-packages/pymongo/collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     607             _check_write_command_response(result)
#     608
# --> 609         self.__database.client._retryable_write(
#     610             acknowledged, _insert_command, session)
#     611
#
# ~/.local/lib/python3.9/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1549     def _retryable_write(self, retryable, func, session):
#    1550         """Internal retryable write helper."""
# -> 1551         with self._tmp_session(session) as s:
#    1552             return self._retry_with_session(retryable, func, s, None)
#    1553
#
# /usr/lib/python3.9/contextlib.py in __enter__(self)
#     115         del self.args, self.kwds, self.func
#     116         try:
# --> 117             return next(self.gen)
#     118         except StopIteration:
#     119             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.9/site-packages/pymongo/mongo_client.py in _tmp_session(self, session, close)
#    1946             return
#    1947
# -> 1948         s = self._ensure_session(session)
#    1949         if s:
#    1950             try:
#
# ~/.local/lib/python3.9/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1933             # Don't make implicit sessions causally consistent. Applications
#    1934             # should always opt-in.
# -> 1935             return self.__start_session(True, causal_consistency=False)
#    1936         except (ConfigurationError, InvalidOperation):
#    1937             # Sessions not supported, or multiple users authenticated.
#
# ~/.local/lib/python3.9/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1881
#    1882         # Raises ConfigurationError if sessions are not supported.
# -> 1883         server_session = self._get_server_session()
#    1884         opts = client_session.SessionOptions(**kwargs)
#    1885         return client_session.ClientSession(
#
# ~/.local/lib/python3.9/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1919     def _get_server_session(self):
#    1920         """Internal: start or resume a _ServerSession."""
# -> 1921         return self._topology.get_server_session()
#    1922
#    1923     def _return_server_session(self, server_session, lock):
#
# ~/.local/lib/python3.9/site-packages/pymongo/topology.py in get_server_session(self)
#     518             # Sessions are always supported in load balanced mode.
#     519             if not self._settings.load_balanced:
# --> 520                 session_timeout = self._check_session_support()
#     521             else:
#     522                 # Sessions never time out in load balanced mode.
#
# ~/.local/lib/python3.9/site-packages/pymongo/topology.py in _check_session_support(self)
#     497             if self._description.topology_type == TOPOLOGY_TYPE.Single:
#     498                 if not self._description.has_known_servers:
# --> 499                     self._select_servers_loop(
#     500                         any_server_selector,
#     501                         self._settings.server_selection_timeout,
#
# ~/.local/lib/python3.9/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     216             # No suitable servers.
#     217             if timeout == 0 or now > end_time:
# --> 218                 raise ServerSelectionTimeoutError(
#     219                     "%s, Timeout: %ss, Topology Description: %r" %
#     220                     (self._error_message(selector), timeout, self.description))
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused, Timeout: 30s, Topology Description: <TopologyDescription id: 6183fae8909a5ae81cda4449, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused')>]>
